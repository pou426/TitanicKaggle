# %%
import pandas as pd
import numpy as np

# visualisation
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df = pd.read_csv('input/train.csv')
test_df = pd.read_csv('input/test.csv')
combine_df = [train_df, test_df]

# %% [markdown]
# ## describing data

# %% [markdown]
# Features in dataset: https://www.kaggle.com/c/titanic/data

# %%
print('training set shape: '+str(train_df.shape))
print('testing set shape: '+str(test_df.shape))
train_df.describe()
# missing data in Age
# Out:
# training set shape: (891, 12)
# testing set shape: (418, 11)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.describe(include=['O']) 
# two missing values in embarked
# Out:
#                              Name   Sex    Ticket        Cabin Embarked
# count                         891   891       891          204      889
# unique                        891     2       681          147        3
# top     Graham, Mr. George Edward  male  CA. 2343  C23 C25 C27        S
# freq                            1   577         7            4      644

# %%
print (train_df.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
print 'training set column datatypes: '
print 'PassengerId: '+str(train_df.Parch.dtype)
print 'Survived: '+str(train_df.Survived.dtype)
print 'Pclass: '+str(train_df.Age.dtype)
print 'Name: ' +str(train_df.Name.dtype)
print 'Sex: ' +str(train_df.Sex.dtype)
print 'Age: ' +str(train_df.Age.dtype)
print 'SibSp: '+str(train_df.SibSp.dtype)
print 'Parch: '+str(train_df.Parch.dtype)
print 'Ticket: ' +str(train_df.Ticket.dtype)
print 'Fare: '+str(train_df.Fare.dtype)
print 'Cabin: ' +str(train_df.Cabin.dtype)
print 'Embarked: ' +str(train_df.Embarked.dtype)
# Out:
# training set column datatypes:
# PassengerId: int64
# Survived: int64
# Pclass: float64
# Name: object
# Sex: object
# Age: float64
# SibSp: int64
# Parch: int64
# Ticket: object
# Fare: float64
# Cabin: object
# Embarked: object

# %%
# inspect the data
train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ### Pivoting features

# %%
train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train_df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train_df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# ## Visualising data

# %%
# fig, (axis1,axis2) = plt.subplots(2,1)
g = sns.factorplot('Survived', col='Embarked',  
                  data=train_df[train_df.Pclass.notnull()],
                  kind='count', size=2.5, aspect=.8)
g = sns.FacetGrid(train_df, col='Embarked', size=2.5, aspect=.8)
g.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
g.add_legend()
plt.show()
# C = Cherbourg, Q = Queenstown, S = Southampton
# correlation between survival and embarkation

# %%
# g = sns.FacetGrid(train_df, col='Embarked', size=2.5, aspect=.8)
# g.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='deep')
# g.add_legend()
# plt.show()

# %%
g = sns.factorplot('Survived', col='Pclass',  
                  data=train_df[train_df.Pclass.notnull()],
                  kind='count', size=2.5, aspect=.8)
plt.show()

# %%
g = sns.factorplot('Survived', col='Sex',  
                  data=train_df[train_df.Pclass.notnull()],
                  kind='count', size=2.5, aspect=.8)
plt.show()

# %%
g = sns.FacetGrid(train_df, col='Survived', hue='Sex')
# g = sns.FacetGrid(train_df, col='Survived')
g = (g.map(plt.hist, 'Age', bins=20).add_legend())

# %%
grid = sns.FacetGrid(train_df, col='Survived', size=2.2, aspect=1.6, row='Pclass')
grid.map(plt.hist, 'Age', bins=20)
grid.add_legend();

# %%
g = sns.FacetGrid(train_df, col="Survived", size=2.2, aspect=1.6, row="Sex")
g = g.map(plt.hist, "Age")
g.add_legend()

# %%
grid = sns.FacetGrid(train_df, row='Embarked', col='Survived', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', ci=None)
grid.add_legend()

# %% [markdown]
# ### drop unnecessary columns

# %%
train_df = train_df.drop(['PassengerId','Ticket','Cabin'], axis=1)
test_df = test_df.drop(['PassengerId','Ticket','Cabin'], axis=1)

# %% [markdown]
# ### fill in missing values
#
# #### Embarked

# %%
# Only two missing values in Embarked, fill them in with median = "S"
train_df["Embarked"] = train_df["Embarked"].fillna("S")

# %%
sns.factorplot('Embarked','Survived',data=train_df,size=4,aspect=3)
fig, (axis1,axis2,axis3) = plt.subplots(1,3,figsize=(15,5))
sns.countplot(x='Embarked', data=train_df, ax=axis1)
sns.countplot(x='Survived', hue="Embarked", data=train_df, ax=axis2)
# group by embarked and find mean of survival for each group
embarked_group = train_df[['Embarked','Survived']].groupby(['Embarked'],as_index=False).mean()
sns.barplot(x='Embarked', y='Survived',data=embarked_group,order=['S','C','Q'],ax=axis3)

# %% [markdown]
# #### Fare

# %%
# for test_df, there is one missing value
test_df["Fare"].fillna(test_df["Fare"].median(), inplace=True)

train_df['Fare'] = train_df['Fare'].astype(int)
test_df['Fare'] = test_df['Fare'].astype(int)

fare_survived = train_df['Fare'][train_df['Survived']==1]
fare_not_survived = train_df['Fare'][train_df['Survived']==0]

mean_fare_survived = fare_survived.mean()
med_fare_survived = fare_survived.median()
mode_fare_survived = fare_survived.mode()
print 'survived & fare: mean = ' + str(mean_fare_survived) + \
                      ', median = ' + str(med_fare_survived) + \
                      ', mode = ' + str(mode_fare_survived)

train_df['Fare'].plot(kind='hist', bins=300, xlim=(0,50))
# Out:
# survived & fare: mean = 47.9912280702, median = 26.0, mode = 0    7
# dtype: int64

# %% [markdown]
# #### Age

# %%
# train_df['Age'].plot(kind='hist', xlim=(0,100))
print 'There are ' + str(train_df.Age.count()) + ' age values'

fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,4))
axis1.set_title('Original Age values - Titanic')
axis2.set_title('New Age values - Titanic')
train_df['Age'].dropna().astype(int).hist(bins=70, ax=axis1)

# get average, std, and number of NaN values in titanic_df
average_age_df   = train_df["Age"].mean()
std_age_df       = train_df["Age"].std()
count_nan_age_df = train_df["Age"].isnull().sum()

# get average, std, and number of NaN values in test_df
average_age_test   = test_df["Age"].mean()
std_age_test       = test_df["Age"].std()
count_nan_age_test = test_df["Age"].isnull().sum()

# Todo: determine an underlying distribution and generate random number from that distribution
# generate random numbers between (mean - std) & (mean + std)
rand_1 = np.random.randint(average_age_df - std_age_df, average_age_df + std_age_df, size = count_nan_age_df)
rand_2 = np.random.randint(average_age_test - std_age_test, average_age_test + std_age_test, size = count_nan_age_test)

# fill NaN values in Age column with random values generated
train_df["Age"][np.isnan(train_df["Age"])] = rand_1
test_df["Age"][np.isnan(test_df["Age"])] = rand_2

train_df['Age'].hist(bins=70, ax=axis2)
# Out:
# There are 714 age values
# /Users/home/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/home/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
### TODO:
# # peaks for survived/not survived passengers by their age
# facet = sns.FacetGrid(train_df, hue="Survived",aspect=4)
# facet.map(sns.kdeplot,'Age',shade= True)
# facet.set(xlim=(0, train_df['Age'].max()))
# facet.add_legend()

# # average survived passengers by age
# fig, axis1 = plt.subplots(1,1,figsize=(18,4))
# average_age = train_df[["Age", "Survived"]].groupby(['Age'],as_index=False).mean()
# sns.barplot(x='Age', y='Survived', data=average_age)

# %% [markdown]
# ### Create new feature to combine Parch + SibSp

# %%
train_df['FamilySize'] = train_df['SibSp'] + train_df['Parch'] + 1
test_df['FamilySize'] = test_df['SibSp'] + test_df['Parch'] + 1

train_df.head()
train_df[['FamilySize','Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived',ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
test_df.head()
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    Parch  Fare Embarked  FamilySize
# 0      0     7        Q           1
# 1      0     7        S           2
# 2      0     9        Q           1
# 3      0     8        S           1
# 4      1    12        S           3

# %% [markdown]
# ## Visualising data

# %%
# g = sns.FacetGrid(train_df, col='Survived', row='Pclass')
# g = (g.map(plt.hist, 'Age', bins=20).add_legend())
